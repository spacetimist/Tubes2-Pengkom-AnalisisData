# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Albert\\anaconda101\\Tubesbert\\PS4_GamesSales.csv", header=0, encoding='unicode_escape')

# %%
df.dropna(inplace=True)
df1=pd.DataFrame(df.reset_index(drop=True))
df1.to_csv("PS4_GamesSalesClean.csv")

# %%
dfc = pd.read_csv("C:\\Users\\Albert\\anaconda101\\Tubesbert\\PS4_GamesSalesClean.csv", header=0, encoding='unicode_escape')

# %%
print(dfc)
# Out:
#      Unnamed: 0                       Game    Year             Genre  \
# 0             0         Grand Theft Auto V  2014.0            Action
# 1             1  Call of Duty: Black Ops 3  2015.0           Shooter
# 2             2      Red Dead Redemption 2  2018.0  Action-Adventure
# 3             3         Call of Duty: WWII  2017.0           Shooter
# 4             4                    FIFA 18  2017.0            Sports
# ..          ...                        ...     ...               ...
# 820         820                  Biomutant  2019.0            Action
# 821         821                    de Blob  2017.0          Platform
# 822         822           Chaos on Deponia  2017.0         Adventure
# 823         823                  Code Vein  2018.0            Action
# 824         824   Radial G Racing Revolved  2017.0            Racing
#
#                       Publisher  North America  Europe  Japan  Rest of World  \
# ...

# %% [markdown]
# Jika angka korelasi semakin mendekati 0 maka kedua atribut semakin tidak berkorelasi
# Jika angka korelasi semakin mendekati 1 maka kedua atribut semakin berkorelasi dan berbanding lurus
# Jika angka korelasi semakin mendekati -1 maka kedua atribut semakin berkorelasi dan berbanding terbalik

# %%
print("Korelasi antara penjualan di North America dengan Europe",dfc["North America"].corr(dfc["Europe"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di North America dengan Europe 0.8107281993891672

# %%
print("Korelasi antara penjualan di North America dengan Japan",dfc["North America"].corr(dfc["Japan"]))
#Tidak memiliki korelasi
# Out:
# Korelasi antara penjualan di North America dengan Japan 0.3893566613186411

# %%
print("Korelasi antara penjualan di North America dengan Rest of World",dfc["North America"].corr(dfc["Rest of World"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di North America dengan Rest of World 0.9516302743678055

# %%
print("Korelasi antara penjualan di North America dengan Global",dfc["North America"].corr(dfc["Global"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di North America dengan Global 0.9363472835228139

# %%
print("Korelasi antara penjualan di Europe dengan Japan",dfc["Europe"].corr(dfc["Japan"]))
#Tidak memiliki korelasi
# Out:
# Korelasi antara penjualan di Europe dengan Japan 0.3597390178784072

# %%
print("Korelasi antara penjualan di Europe dengan Rest of World",dfc["Europe"].corr(dfc["Rest of World"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di Europe dengan Rest of World 0.9512934033875065

# %%
print("Korelasi antara penjualan di Europe dengan Global",dfc["Europe"].corr(dfc["Global"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di Europe dengan Global 0.9613059131698339

# %%
print("Korelasi antara penjualan di Japan dengan Rest of World",dfc["Japan"].corr(dfc["Rest of World"]))
#Tidak memiliki korelasi
# Out:
# Korelasi antara penjualan di Japan dengan Rest of World 0.39382372072644106

# %%
print("Korelasi antara penjualan di Japan dengan Global",dfc["Japan"].corr(dfc["Global"]))
#Tidak memiliki korelasi
# Out:
# Korelasi antara penjualan di Japan dengan Global 0.448418651641273

# %%
print("Korelasi antara penjualan di Rest of World dengan Global",dfc["Rest of World"].corr(dfc["Global"]))
#Memiliki korelasi berbanding lurus
# Out:
# Korelasi antara penjualan di Rest of World dengan Global 0.9971341042250587

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["North America"].corr(dfc["Europe"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di North America dengan Europe")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["North America"].corr(dfc["Japan"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di North America dengan Japan")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["North America"].corr(dfc["Rest of World"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di North America dengan Rest of World")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["North America"].corr(dfc["Global"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di North America dengan Global")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Europe"].corr(dfc["Japan"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Europe dengan Japan")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Europe"].corr(dfc["Rest of World"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Europe dengan Rest of World")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Europe"].corr(dfc["Global"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Europe dengan Global")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Japan"].corr(dfc["Rest of World"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Japan dengan Rest of World")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Japan"].corr(dfc["Global"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Japan dengan Global")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')

# %%
dfc["Year"]=dfc["Year"].astype(int)
dfc.groupby("Year")["Rest of World"].corr(dfc["Global"]).plot(kind="bar")
plt.title("Grafik Korelasi per tahun antara penjualan di Rest of World dengan Global")
plt.ylabel("Korelasi")
plt.xlabel("Tahun")
# Out:
# Text(0.5, 0, 'Tahun')
